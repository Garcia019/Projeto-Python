# %% [markdown]
# ## Callable Object
# ***S11 A132***
#
# Nessa aula vamos dar inicio ao aprendizado de Callable objetos, mostrando que um objeto pode sert comportar com uma função o que são chamados de objetos chamados, callable object, vamos iniciar os exemplos, envolvendo classe e objeto, com orientação ao objeto,

# %%
# Criando Classse e testeando o Callable Object

# Define um bloco e um bloco associado a esta classe
class Potencia:
    # Calcular uma potência específica de algum número
    # Criando um construtor com __init__()
    # métodos ou funções que pertencem a uma classe
    # Sempre devem iniciar com self
    # Sendo que o primeiro Parâmetro representa a instancia atual
    def __init__(self, expoente):
        self.expoente = expoente

    # Essa função call ela é criada pois toda vez que chamarmos
    # o objeto potencia como função vamos chamar o metodo call dentro da classe potencia
    def __call__(self, base):
        return base ** self.expoente


if __name__ == "__main__":
    # Nesse caso eu crio um objeto definindo inicialmente o tipo de expoente\
    # E dou nome a ele no caso quadrado representa o objeto Potencia com expoente 2
    # E cubo objeto potencia com expoente 3
    quadrado = Potencia(2)
    cubo = Potencia(3)
    if callable(quadrado) and
