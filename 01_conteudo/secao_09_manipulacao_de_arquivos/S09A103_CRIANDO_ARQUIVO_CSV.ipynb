# %% [markdown]
# ## Criando Arquivo CSV
# ***S09 A103***
#
# Nessa seção vamos lidar com a manipulação de arquivos e nessa aula vamos aprender a criar um arquivo CSV(Comma-Separated Values, ou valores separados por vírgula) incialmente, criamos o arquivo de forma manual e adicionamops alguns dados a esse arqiuivo para maniupalação futura dos dados utilizando o python, o professor mostrou tambem nessa aula um pouco da funcionalidade do * no uso de listas e tuplas vou mostrar um pouco melhor abaixo,

# %% [markdown]
# # Criamos o Arquivo Manualmente pessoas.csv
#
# Com isso colocamos os seguinte dados dentro do arquivo,
#
# Maria,45
# João,33
# Pedro,63
# Ana,21
# Bia,40
# Carlos,14

# %%
# Os exemplos abaixo são exatamente mostram exatamente a utilização do format com strings e posições de uma lista ou tupla
# Considerando também ser possível inderessar as palavras definidas no .format como exemplo a frase 2

frase1 = "O aluno {} é {}!".format("Matheus", "Inteligente")
frase2 = "A nota do aluno {2} em {0} foi {1}".format("João", "História", "10") # Frase 4:  A nota do aluno Lucas em História foi 8.5

print("Frase 1: ",frase1)
print("Frase 2: ",frase2)

lista_palavra = ["Roberto", "Lindo"]
tupla_palavra = ("Lucas" , "História", 8.5)

# Frase 3 e 4 exemplos de formatação com a utilização das posições de uma tupla ou lista

frase3 = "O aluno {} é {}!".format(lista_palavra[0], lista_palavra[1])
print("Frase 3: ", frase3)

frase4 = "A nota do aluno {} em {} foi {}".format(tupla_palavra[0], tupla_palavra[1], tupla_palavra[2])
print("Frase 4: ", frase4)

# Frase 5 e 6 demonstra exemplos utilizando o *lista que ja atribui cada item da lista ao espaços em ordem de posição

lista_palavra2 = ["Carlos", "Feio"]
tupla_palavra2 = ("Renan" , "Português", 7.5)

frase5 = "O aluno {} é {}!".format(*lista_palavra2) # utilizando o "*" conseguimos colocar em ordem os parametros da lista ou tupla
print("Frase 5: ", frase5)

frase6 = "A nota do aluno {} em {} foi {}".format(*tupla_palavra2)# utilizando o "*" conseguimos colocar em ordem os parametros da lista ou tupla
print("Frase 6: ", frase6)

# frase7 = "O aluno {} é {} e {}!".format(*lista_palavra2) - causa erro pois o tamanho de espaços para preencher é maior que o da lista 
print(frase7)
# Out:
# Frase 1:  O aluno Matheus é Inteligente!
# Frase 2:  A nota do aluno 10 em João foi História
# Frase 3:  O aluno Roberto é Lindo!
# Frase 4:  A nota do aluno Lucas em História foi 8.5
# Frase 5:  O aluno Carlos é Feio!
# Frase 6:  A nota do aluno Renan em Português foi 7.5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 32
#      29 frase6 = "A nota do aluno {} em {} foi {}".format(*tupla_palavra2)# utilizando o "*" conseguimos colocar em ordem os parametros da lista ou tupla
#      30 print("Frase 6: ", frase6)
# ---> 32 frase7 = "O aluno {} é {} e {}!".format(*lista_palavra2)
#      33 print(frase7)
#
# IndexError: Replacement index 2 out of range for positional args tuple
